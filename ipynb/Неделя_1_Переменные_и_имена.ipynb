# %% [markdown]
# # 🐍 Неделя 1 — Переменные и имена: пошаговая практика
# Формат каждого блока: **A) запускаем хороший код**, **B) намеренно ломаем и читаем трейсбек**, **C) пишем свой код**.
# Идём сверху вниз, по одному маленькому шагу на ячейку.

# %% [markdown]
# ## Список понятий (шпаргалка на сегодня)
# - **Переменная** — имя (ярлык), которое указывает на объект в памяти.
# - **Имя (идентификатор)** — слово вида `snake_case`, которым мы называем переменные и функции.
# - **Тип** — вид объекта: `int`, `float`, `str`, `bool`, коллекции (`list`, `tuple`, `dict`, `set`), `NoneType` и т.д.
# - **Литерал** — записанное прямо значение: `42`, `3.14`, `'текст'`, `True`, `None`.
# - **Ключевое слово (keyword)** — зарезервированное слово Python (например, `for`, `if`, `class`) — **нельзя** использовать как имя переменной.
# - **Выражение** — комбинация значений, переменных и операторов, которую можно вычислить.
# - **Оператор** — символы и слова для действий: `+ - * / // % **`, `=`, `==`, `and`, `in` и др.
# - **Присваивание** — связывание имени и объекта: `x = 10`.
# - **Отступ** — важная часть синтаксиса: 4 пробела формируют блоки кода.
# - **Блок** — группа строк под одним отступом (например, внутри `if`/`for`).
# - **Трейсбек** — сообщение об ошибке: где и что пошло не так.
# - **Встроенная функция (built-in)** — доступные из коробки: `print`, `len`, `type`, `sum`, `abs`, `round`, `min`, `max` и др.
# - **Изменяемые / неизменяемые** — можно ли менять объект «на месте»: `list/dict/set` — изменяемые; `int/str/tuple/bool/NoneType` — нет.

# %% [markdown]
# ## 0. Проверка окружения

# %%
print("Colab готов ✅")
# Out:
# Colab готов ✅

# %% [markdown]
# ## 1. Имена переменных (PEP 8): A) Запускаем правильный код — маленькими шагами

# %% [markdown]
# ### A.1 `book_title` — строка

# %%
book_title = '"Филологические мемы"'
print(book_title)
# Out:
# "Филологические мемы"

# %%
book_title = ""
print(book_title)

# %%
another_book_title = book_title
print(another_book_title)
# Out:
# 12

# %%
book_title = 12
print(book_title)
# Out:
# 12

# %%
print(type(book_title))  # ожидаем: <class 'str'>
# Out:
# <class 'int'>

# %%
book_title_type = type(book_title)
print(book_title_type)
# Out:
# <class 'str'>

# %% [markdown]
# ### A.2 `year` — целое число

# %%
year = 2025
print(year)
# Out:
# 2025

# %%
# ожидаем: <class 'int'>
print(type(year))
# Out:
# <class 'int'>

# %% [markdown]
# ### A.3 `total_words` — целое число

# %%
total_words = 12345
print(total_words)
# Out:
# 12345

# %%
print(type(total_words))
# Out:
# <class 'int'>

# %%
example = 0.12
print(type(example))
# Out:
# <class 'float'>

# %% [markdown]
# ### A.4 `is_long` — булево значение

# %%
check = False
print(check)
print(type(check))
# Out:
# False
# <class 'bool'>

# %%
total_words > 10000
# Out:
# True

# %%
is_long = total_words > 10000
print(is_long)
# Out:
# True

# %%
print(type(is_long))  # ожидаем: <class 'bool'>
# Out:
# <class 'bool'>

# %%
book_title = "Гарри Поттер"
print(book_title, another_book_title)
# Out:
# Гарри Поттер 12

# %% [markdown]
# ## 1. Имена переменных: B) Ломаем и читаем ошибку

# %% [markdown]
# Раскомментируйте **по одной строке** и запустите, чтобы увидеть `SyntaxError`. Потом верните `#`.

# %%
class = 1      # зарезервированное слово
# for = 2        # зарезервированное слово
# if = 3         # зарезервированное слово
# 2cool = 5      # имя не может начинаться с цифры
# bad-name = 10  # дефис — это вычитание, а не часть имени
# Out:
#   File "/tmp/ipython-input-957581797.py", line 1
#     class = 1      # зарезервированное слово
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1. Имена переменных: C) Напишите сами

# %% [markdown]
# Создайте три переменные с **хорошими именами**: `main_character` (str), `page_count` (int), `is_classic` (bool). Выведите на печать их значения и их типы.

# %%
# TODO: ваш код здесь

# %% [markdown]
# ## 2. Зарезервированные слова — шпаргалка (просто запустите)

# %%
import keyword
keyword.kwlist  # список ключевых слов Python
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## 3. Стили именования — мини‑демо

# %% [markdown]
# Переведём поле `camelCase` из чужого API в наш `snake_case` (это просто строковый пример):

# %%
api_field = "totalWords"     # как в JS
python_name = "total_words"  # как в Python
print(api_field, "→", python_name)
# Out:
# totalWords → total_words

# %% [markdown]
# ## 4. Присваивание и обновление: A) Запускаем правильный код — по шагам

# %% [markdown]
# ### A.1 Обмен значениями

# %%
a = 1
b = 2
a, b = b, a
print("a=", a, "b=", b)
# Out:
# a= 2 b= 1

# %% [markdown]
# ### A.2 Увеличение счётчика

# %%
score = 10
score += 7
score *= 10
print("score=", score)
# Out:
# score= 170

# %% [markdown]
# ## 4. Присваивание и обновление: B) Ломаем и читаем ошибку

# %% [markdown]
# Раскомментируйте и запустите: смешиваем число и строку → `TypeError`. Затем исправьте на следующей строке.

# %%
# score += "5"        # TypeError: unsupported operand type(s) for +=: 'int' and 'str'
score = score + int("5")  # фикс
print("score=", score)
# Out:
# score= 195

# %%
a = int("5")
b = str(5)
print(a, type(a), b, type(b))
# Out:
# 5 <class 'int'> 5 <class 'str'>

# %% [markdown]
# ## 4. Присваивание и обновление: C) Напишите сами

# %% [markdown]
# Создайте `gryffindor = 10`, увеличьте на 7 с помощью `+=`, выведите значение.

# %%
# TODO: ваш код

# %% [markdown]
# ## 5. Переменная → объект: A) Запускаем правильный код

# %% [markdown]
# ### A.1 Aliasing (два имени для одного списка)

# %%
numbers = [1, 2]
alias = numbers
alias.append(3)
print("numbers:", numbers, "| alias:", alias)
print("Один и тот же объект?", id(numbers) == id(alias))

# %% [markdown]
# ### A.2 Неизменяемые значения создают новый объект

# %%
x = 10
y = x
y += 1
print("x:", x, "| y:", y, "| Один и тот же объект?", id(x) == id(y))
# Out:
# x: 10 | y: 11 | Один и тот же объект? False

# %% [markdown]
# ## 5. Переменная → объект: B) Ломаем и читаем ошибку

# %% [markdown]
# Нельзя присваивать в **литерал**. Раскомментируйте, получите `SyntaxError`, верните `#`.

# %%
# 10 += 1   # SyntaxError: нельзя присваивать в литерал

# %% [markdown]
# ## 5. Переменная → объект: C) Напишите сами

# %% [markdown]
# Создайте `words = ['гарри','питон']`, присвойте `w = words`, добавьте `'мем'` через `.append(...)`. Выведите обе переменные.

# %%
# TODO: ваш код
words = ['гарри','питон']
w = words
w.append('мем')
print("words:", words)
print("w:", w)
# Out:
# words: ['гарри', 'питон', 'мем']
# w: ['гарри', 'питон', 'мем']

# %% [markdown]
# ## 6. Типы данных: A) Запускаем правильный код — краткая витрина

# %%
sample_int = 42
sample_float = 3.14
sample_str = "текст"
sample_bool = False
print(type(sample_int), type(sample_float), type(sample_str), type(sample_bool))

# %% [markdown]
# ## 6. Типы данных: B) Ломаем и читаем ошибку

# %% [markdown]
# `len(...)` работает для последовательностей/коллекций. Попробуем на числе → `TypeError`. Затем исправим на строке.

# %%
# len(10)           # TypeError
print(len("Привет"))  # фикс

# %% [markdown]
# ## 6. Типы данных: C) Напишите сами

# %% [markdown]
# Создайте `pages = 350` и `title = 'Гарри Поттер'`. Выведите их типы и длину `title`.

# %%
# TODO: ваш код
pages = 350
title = "Гарри Поттер"
print(type(pages), type(title))
print(len(title))

# %% [markdown]
# ## 7. Выражения и операции: A) Запускаем правильный код

# %%
print(2 + 2 * 2)               # 6
print("la" * 3)                # 'lalala'
print("год: " + str(1866))     # конкатенация со str()

# %% [markdown]
# ## 7. Выражения и операции: B) Ломаем и читаем ошибку

# %% [markdown]
# Раскомментируйте: сложение строки и числа → `TypeError`. Затем верните `#`.

# %%
# "год: " + 1866

# %% [markdown]
# ## 7. Выражения и операции: C) Напишите сами

# %% [markdown]
# Соберите одну строку через f-строку: `f"{title} ({year}), страниц: {pages}"` и выведите её.

# %%
# TODO: ваш код
title = "Гарри Поттер"
year = 1997
pages = 350
info = f"Book {title} was published ({year}), pages: {pages}"
print(len(info))
# Out:
# 50

# %%
sum([5, 10])
# Out:
# 15

# %% [markdown]
# ## 8. Встроенные функции (минимум): A) Запускаем правильный код

# %%
print("a","b","c", sep="|", end="!\n")
# Out:
# a|b|c!

# %%
len(another_book_title)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-532346466.py in <cell line: 0>()
# ----> 1 len(another_book_title)
#
# TypeError: object of type 'int' has no len()

# %%
print(len([1,2,3]), abs(-5), round(3.14159, 2))
# Out:
# 3 5 3.14

# %%
print(type(3.0), str(10), int("42"))
# Out:
# <class 'float'> 10 42

# %% [markdown]
# ## 8. Встроенные: B) Ломаем и читаем ошибку

# %% [markdown]
# Перекрытие встроенных: раскомментируйте, чтобы сломать `list`, затем `del list` и вызовите снова.

# %%
# list = [1,2,3]       # плохая идея: перезапишет встроенный тип list
# list((1,2,3))        # TypeError: 'list' object is not callable
# del list
# print(list((1,2,3))) # фикс

# %% [markdown]
# ## 8. Встроенные: C) Напишите сами

# %% [markdown]
# Выведите количество букв в `book_title` **без пробелов**: используйте `replace(' ', '')` и `len(...)`.

# %%
# TODO: ваш код
cleaned = book_title.replace(" ", "")
print(len(cleaned))

# %% [markdown]
# ---
# ## 9. Итоговое мини‑задание: паспорт книги

# %% [markdown]
# Используйте `title`, `author`, `year`, `pages`, `is_classic`. Выведите одну строку (f-строка):
# `Название — {title}; автор — {author}; год — {year}; страниц — {pages}; классика? {is_classic}`

# %%
# TODO: ваш код
author = "Джоан Роулинг"
passport = f"Название — {title}; автор — {author}; год — {year}; страниц — {pages}; классика? {is_classic}"
print(passport)
