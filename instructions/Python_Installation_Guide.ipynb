# %% [markdown]
# # 🐍 Установка Python на ваш компьютер
#
# **Модуль 2, Неделя 8**
#
# Это пошаговое руководство по установке Python на Windows и macOS.
#
# ---
#
# ## 📋 Что мы сделаем?
#
# 1. ✅ Скачаем Python с официального сайта
# 2. ✅ Установим Python правильно
# 3. ✅ Проверим что всё работает
# 4. ✅ Запустим первый локальный скрипт
#
# **Время:** ~30 минут
#
# ---

# %% [markdown]
# ## 🪟 Часть 1: Установка на Windows
#
# ### Шаг 1: Скачать Python
#
# 1. Откройте браузер
# 2. Перейдите на **[python.org/downloads](https://www.python.org/downloads/)**
# 3. Нажмите большую жёлтую кнопку **"Download Python 3.11.x"** (или новее)
#    - Файл будет называться примерно `python-3.11.5-amd64.exe`
#    - Размер: около 25 МБ
# 4. Дождитесь окончания загрузки (обычно в папке "Загрузки")
#
# ---
#
# ### Шаг 2: Запустить установщик
#
# 1. Найдите скачанный файл в папке **Загрузки**
# 2. Двойной клик по файлу `python-3.11.x-amd64.exe`
# 3. **⚠️ ОЧЕНЬ ВАЖНО!** В первом окне установщика:
#
#    ```
#    ┌─────────────────────────────────────────────┐
#    │  Install Python 3.11.5                      │
#    │                                             │
#    │  ☑ Install launcher for all users          │
#    │  ☑ Add Python 3.11 to PATH   ← ВАЖНО!      │
#    │                                             │
#    │  [Install Now]  [Customize installation]   │
#    └─────────────────────────────────────────────┘
#    ```
#
# 4. **ОБЯЗАТЕЛЬНО** поставьте галочку ☑ **"Add Python to PATH"**
#    - Без этой галочки Python не будет работать в командной строке!
# 5. Нажмите **"Install Now"**
# 6. Если появится запрос UAC (Контроль учётных записей) → нажмите **"Да"**
#
# ---
#
# ### Шаг 3: Дождаться окончания установки
#
# 1. Установка займёт 2-3 минуты
# 2. Вы увидите прогресс-бар:
#    ```
#    Installing:
#    ████████████████████ 100%
#    ```
# 3. Когда появится **"Setup was successful"** → нажмите **"Close"**
#
# ✅ **Python установлен!**
#
# ---
#
# ### Шаг 4: Проверить установку
#
# #### Открыть командную строку:
#
# **Способ 1:**
# 1. Нажмите **Win + R**
# 2. Напечатайте `cmd`
# 3. Нажмите **Enter**
#
# **Способ 2:**
# 1. Нажмите кнопку **Пуск**
# 2. Найдите **"Командная строка"** или **"cmd"**
# 3. Откройте её
#
# #### Проверить версию Python:
#
# В чёрном окне командной строки напечатайте:
#
# ```cmd
# python --version
# ```
#
# **Ожидаемый результат:**
# ```
# Python 3.11.5
# ```
#
# Если видите версию Python → **Отлично! ✅**
#
# ---
#
# ### Шаг 5: Проверить pip
#
# pip — менеджер пакетов Python (установится автоматически)
#
# В командной строке напечатайте:
#
# ```cmd
# pip --version
# ```
#
# **Ожидаемый результат:**
# ```
# pip 23.2.1 from C:\Users\...\Python311\...
# ```
#
# ✅ **Готово! Python и pip установлены на Windows**
#
# ---

# %% [markdown]
# ## 🍎 Часть 2: Установка на macOS
#
# ### Шаг 1: Проверить что уже установлено
#
# На Mac часто уже есть Python (но старая версия 2.x)
#
# #### Открыть Terminal:
#
# **Способ 1:**
# 1. Нажмите **Cmd + Space** (Spotlight)
# 2. Напечатайте **"Terminal"**
# 3. Нажмите **Enter**
#
# **Способ 2:**
# 1. Откройте **Finder**
# 2. Перейдите в **Приложения → Утилиты → Terminal**
#
# #### Проверить установлен ли Python 3:
#
# В Terminal напечатайте:
#
# ```bash
# python3 --version
# ```
#
# **Если видите:**
# ```
# Python 3.11.x
# ```
# → **Python уже установлен!** Можете пропустить установку ✅
#
# **Если видите:**
# ```
# command not found: python3
# ```
# → Нужно установить Python (переходите к шагу 2)
#
# ---
#
# ### Шаг 2: Скачать Python (если нужно)
#
# 1. Откройте браузер
# 2. Перейдите на **[python.org/downloads](https://www.python.org/downloads/)**
# 3. Нажмите **"Download Python 3.11.x"** (или новее)
#    - Файл будет называться примерно `python-3.11.5-macos11.pkg`
#    - Размер: около 40 МБ
# 4. Дождитесь окончания загрузки
#
# ---
#
# ### Шаг 3: Установить Python
#
# 1. Найдите скачанный файл (обычно в папке **Загрузки**)
# 2. Двойной клик по файлу `python-3.11.x-macos11.pkg`
# 3. Откроется установщик:
#    ```
#    ┌─────────────────────────────────────┐
#    │  Install Python 3.11.5              │
#    │                                     │
#    │  This package will install Python  │
#    │  3.11 for macOS.                    │
#    │                                     │
#    │              [Continue]             │
#    └─────────────────────────────────────┘
#    ```
# 4. Нажимайте **"Продолжить"** → **"Продолжить"** → **"Установить"**
# 5. Введите **пароль администратора** (если попросит)
# 6. Дождитесь окончания установки (2-3 минуты)
# 7. Когда появится **"Установка завершена"** → нажмите **"Закрыть"**
#
# ✅ **Python установлен!**
#
# ---
#
# ### Шаг 4: Проверить установку
#
# Откройте Terminal (если закрыли) и напечатайте:
#
# ```bash
# python3 --version
# ```
#
# **Ожидаемый результат:**
# ```
# Python 3.11.5
# ```
#
# ✅ **Отлично!**
#
# ---
#
# ### Шаг 5: Проверить pip
#
# ```bash
# pip3 --version
# ```
#
# **Ожидаемый результат:**
# ```
# pip 23.2.1 from /Library/Frameworks/Python.framework/...
# ```
#
# ✅ **Готово! Python и pip установлены на macOS**
#
# ---
#
# ### ⚠️ Важно для macOS:
#
# На Mac команды:
# - `python3` (не `python`)
# - `pip3` (не `pip`)
#
# **Почему?** На Mac может быть старый Python 2.x как `python`. Используйте `python3`!
#
# ---

# %% [markdown]
# ## 🧪 Часть 3: Тестирование установки
#
# ### Тест 1: Интерактивный режим Python
#
# #### Windows:
# ```cmd
# python
# ```
#
# #### macOS:
# ```bash
# python3
# ```
#
# **Ожидаемый результат:**
# ```python
# Python 3.11.5 (main, ...)
# [GCC ...] on darwin
# Type "help", "copyright", "credits" or "license" for more information.
# >>>
# ```
#
# Символы `>>>` означают что Python ждёт ваших команд!
#
# ---
#
# ### Попробуйте выполнить:
#
# ```python
# >>> print("Привет из локального Python!")
# Привет из локального Python!
#
# >>> 2 + 2
# 4
#
# >>> "Божественная комедия".upper()
# 'БОЖЕСТВЕННАЯ КОМЕДИЯ'
#
# >>> len("Данте Алигьери")
# 15
# ```
#
# Для выхода:
# ```python
# >>> exit()
# ```
#
# ✅ **Если всё это сработало → установка успешна!**
#
# ---

# %% [markdown]
# ## 📝 Часть 4: Создание первого скрипта
#
# Теперь создадим настоящий Python-скрипт и запустим его!
#
# ---
#
# ### Шаг 1: Создать файл
#
# #### Windows (Блокнот):
# 1. Откройте **Блокнот** (Notepad)
# 2. Скопируйте код (см. ниже)
# 3. **Файл → Сохранить как**
# 4. **Важно!** Выберите **"Тип файла: Все файлы"**
# 5. Назовите: `test_installation.py`
# 6. Сохраните в **Документы**
#
# #### macOS (TextEdit):
# 1. Откройте **TextEdit**
# 2. **Формат → Конвертировать в простой текст**
# 3. Скопируйте код (см. ниже)
# 4. **Файл → Сохранить**
# 5. Назовите: `test_installation.py`
# 6. Сохраните в **Documents**
#
# ---
#
# ### Код для скрипта:
#
# ```python
# # Тест установки Python
# # ФИО: [ваше имя]
#
# print("=" * 50)
# print("🐍 Python успешно установлен!")
# print("=" * 50)
#
# # Проверка базовых операций
# print("\nПроверка операций:")
# print(f"  2 + 2 = {2 + 2}")
# print(f"  10 * 5 = {10 * 5}")
#
# # Работа со строками
# text = "Божественная комедия Данте"
# print(f"\nТекст: {text}")
# print(f"  Длина: {len(text)} символов")
# print(f"  Прописными: {text.upper()}")
# print(f"  Строчными: {text.lower()}")
#
# # Работа со списком
# words = text.split()
# print(f"\nСлова: {words}")
# print(f"  Количество: {len(words)}")
#
# print("\n" + "=" * 50)
# print("✅ Всё работает отлично!")
# print("=" * 50)
# ```
#
# ---
#
# ### Шаг 2: Запустить скрипт
#
# #### Windows:
# ```cmd
# cd Documents
# python test_installation.py
# ```
#
# #### macOS:
# ```bash
# cd Documents
# python3 test_installation.py
# ```
#
# ---
#
# ### Ожидаемый вывод:
#
# ```
# ==================================================
# 🐍 Python успешно установлен!
# ==================================================
#
# Проверка операций:
#   2 + 2 = 4
#   10 * 5 = 50
#
# Текст: Божественная комедия Данте
#   Длина: 27 символов
#   Прописными: БОЖЕСТВЕННАЯ КОМЕДИЯ ДАНТЕ
#   Строчными: божественная комедия данте
#
# Слова: ['Божественная', 'комедия', 'Данте']
#   Количество: 3
#
# ==================================================
# ✅ Всё работает отлично!
# ==================================================
# ```
#
# ✅ **Если видите такой вывод → ПОЗДРАВЛЯЮ! Python установлен и работает!**
#
# ---

# %% [markdown]
# ## 🚨 Решение проблем
#
# ### Проблема 1 (Windows): "python is not recognized"
#
# **Ошибка:**
# ```
# 'python' is not recognized as an internal or external command
# ```
#
# **Причина:** Python не добавлен в PATH при установке
#
# **Решение:**
# 1. Удалить Python:
#    - Панель управления → Программы и компоненты
#    - Найти Python 3.11.x
#    - Удалить
# 2. Переустановить Python
# 3. **⚠️ ОБЯЗАТЕЛЬНО поставить галочку "Add Python to PATH"**
#
# ---
#
# ### Проблема 2 (macOS): "command not found: python"
#
# **Ошибка:**
# ```
# command not found: python
# ```
#
# **Решение:** Используйте `python3` вместо `python`
#
# ```bash
# python3 --version
# python3 script.py
# ```
#
# ---
#
# ### Проблема 3: Файл сохранился как .txt
#
# **Признак:** Файл называется `test_installation.py.txt`
#
# **Решение (Windows):**
# 1. В Блокноте при сохранении:
#    - **"Тип файла"** выбрать **"Все файлы"**
#    - Название: `test_installation.py`
#
# **Решение (macOS):**
# 1. В TextEdit сначала:
#    - **Формат → Конвертировать в простой текст**
# 2. Потом сохранить как `.py`
#
# ---
#
# ### Проблема 4: Не могу найти файл
#
# **Ошибка:**
# ```
# python: can't open file 'test_installation.py': No such file or directory
# ```
#
# **Причина:** Вы не в той папке где сохранили файл
#
# **Решение:**
#
# **Windows:**
# 1. Откройте папку с файлом в Проводнике
# 2. Shift + Правая кнопка мыши в пустом месте
# 3. "Открыть окно команд здесь" или "Открыть PowerShell здесь"
#
# **macOS:**
# 1. Откройте Terminal
# 2. Перейдите в правильную папку:
#    ```bash
#    cd ~/Documents
#    ls  # посмотреть список файлов
#    ```
#
# ---
#
# ### Проблема 5 (Windows): Кириллица отображается как �����
#
# **Решение:** Перед запуском скрипта выполнить:
# ```cmd
# chcp 65001
# python test_installation.py
# ```
#
# Или использовать **PowerShell** вместо cmd (там кириллица работает лучше)
#
# ---

# %% [markdown]
# ## ✅ Чек-лист успешной установки
#
# Отметьте что у вас работает:
#
# ### Windows:
# - [ ] `python --version` показывает Python 3.11.x
# - [ ] `pip --version` показывает версию pip
# - [ ] Интерактивный режим запускается (`python` в cmd)
# - [ ] Скрипт `test_installation.py` запускается
# - [ ] Весь вывод корректный (включая кириллицу)
#
# ### macOS:
# - [ ] `python3 --version` показывает Python 3.11.x
# - [ ] `pip3 --version` показывает версию pip
# - [ ] Интерактивный режим запускается (`python3` в Terminal)
# - [ ] Скрипт `test_installation.py` запускается
# - [ ] Весь вывод корректный
#
# **Если всё отмечено → установка полностью успешна! 🎉**
#
# ---

# %% [markdown]
# ## 📸 Домашнее задание
#
# ### Задание: Сделать скриншот работающего скрипта
#
# 1. Запустите скрипт `test_installation.py`
# 2. Убедитесь что весь вывод виден в окне
# 3. Сделайте скриншот
#
# ---
#
# ### Как сделать скриншот?
#
# **Windows:**
# - Способ 1: **PrintScreen** (весь экран) → вставить в Paint
# - Способ 2: **Win + Shift + S** (выбрать область)
# - Сохранить как изображение
#
# **macOS:**
# - Способ 1: **Cmd + Shift + 3** (весь экран)
# - Способ 2: **Cmd + Shift + 4** (выбрать область)
# - Файл сохранится на рабочем столе
#
# ---
#
# ### Что должно быть на скриншоте?
#
# ✅ Командная строка / Terminal
# ✅ Команда запуска (`python test_installation.py`)
# ✅ Весь вывод программы (от начала до "✅ Всё работает отлично!")
# ✅ Нет ошибок
#
# **Загрузите скриншот на платформу курса**
#
# **Дедлайн:** 3 дня
#
# ---

# %% [markdown]
# ## 🎯 Итоги
#
# **Что мы сделали:**
#
# ✅ Установили Python локально (Windows или macOS)
# ✅ Проверили что Python работает
# ✅ Запустили первый скрипт из командной строки
# ✅ Убедились что всё работает правильно
#
# **Вы больше не зависите от Google Colab!**
#
# Теперь можете:
# - Работать с любыми размерами данных
# - Запускать код оффлайн
# - Использовать профессиональные инструменты
#
# ---
#
# ## 🚀 Что дальше?
#
# **Неделя 9:** Установка VSCode (профессиональный редактор)
# **Неделя 10:** Git и GitHub (версионирование кода)
#
# **А пока:** Потренируйтесь запускать разные скрипты локально!
#
# ---
#
# ## 🆘 Нужна помощь?
#
# Если что-то не получилось:
# - Проверьте раздел "Решение проблем" выше
# - Напишите в чат курса
# - Приходите на офис-хаурс
#
# **Не стесняйтесь спрашивать! Технические проблемы — это нормально.** 😊
#
# ---
#
# **Удачи! 🐍✨**
